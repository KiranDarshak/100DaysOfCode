# %% [markdown]
# # Chi-Squared Distribution
#
# Chi-squared distribution used for comparing two distribution. It is build by summing n-normal-distribution squared. How does comparing two distribution using Chi-Squared works?
#
#  -  Divide the two distribution into several segment with the same rule (bound)
#  -  See the difference in each of segment. Difference = (O-E)2/E (normalised)
#
#  - Point (b) should follow normal distribution squared (which is the Chi Squared distribution)
#
#  - Degree of freedom is the number of segment-1
#
#  - End

# %%
data1= rnorm(1000,mean=0,sd=1)
hist (data1)
data1s = data1^2
hist(data1s,n=100)
# Out:
# Plot with title “Histogram of data1”
# Plot with title “Histogram of data1s”

# %%
data2 = rnorm(1000,mean=0,sd=1)
hist(data2)
data1.data2=data1^2+data2^2
hist(data1.data2,n=100)
# Out:
# Plot with title “Histogram of data2”
# Plot with title “Histogram of data1.data2”

# %%
data3 = rnorm(1000,mean=0,sd=1)
hist(data3)
data1.data2.data3=data1^2+data2^2+data3^2
hist(data1.data2.data3,n=100)
# Out:
# Plot with title “Histogram of data3”
# Plot with title “Histogram of data1.data2.data3”

# %%
ChiSqGenerator = function(sample,df){
  chis.data = rep(0,sample)
  for(i in 1:df){
    norm.data = rnorm(sample,mean=0,sd=1)
    chis.data = chis.data+norm.data^2
  }
  
  return(chis.data)
}
n.sample = 100000
n.bin = 100

# %%
# 1 degree
hist(ChiSqGenerator(n.sample,1),n.bin)
d.1 = density(ChiSqGenerator(n.sample,1))
plot(d.1)
# Out:
# Plot with title “Histogram of ChiSqGenerator(n.sample, 1)”
# Plot with title “density.default(x = ChiSqGenerator(n.sample, 1))”

# %%
# 2 degree
hist(ChiSqGenerator(n.sample,2),n.bin)
d.2 = density(ChiSqGenerator(n.sample,2))
plot(d.2)
# Out:
# Plot with title “Histogram of ChiSqGenerator(n.sample, 2)”
# Plot with title “density.default(x = ChiSqGenerator(n.sample, 2))”

# %%
# 5 degree
hist(ChiSqGenerator(n.sample,5),n.bin)
d.5 = density(ChiSqGenerator(n.sample,5))
plot(d.5)
# Out:
# Plot with title “Histogram of ChiSqGenerator(n.sample, 5)”
# Plot with title “density.default(x = ChiSqGenerator(n.sample, 5))”

# %%
# 9 degree
hist(ChiSqGenerator(n.sample,9),n.bin)
d.9 = density(ChiSqGenerator(n.sample,9))
plot(d.9)
# Out:
# Plot with title “Histogram of ChiSqGenerator(n.sample, 9)”
# Plot with title “density.default(x = ChiSqGenerator(n.sample, 9))”

# %%
# 10 degree
hist(ChiSqGenerator(n.sample,10),n.bin)
d.10 = density(ChiSqGenerator(n.sample,10))
plot(d.10)
# Out:
# Plot with title “Histogram of ChiSqGenerator(n.sample, 10)”
# Plot with title “density.default(x = ChiSqGenerator(n.sample, 10))”
