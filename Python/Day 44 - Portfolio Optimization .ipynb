# %% [markdown]
# # Portfolio Optimization
#
# “Modern Portfolio Theory (MPT), a hypothesis put forth by Harry Markowitz, is an investment theory based on the idea that risk-avoiding investors can construct portfolios to optimize or maximize expected return based on a given level of market risk, emphasizing that risk is an inherent part of higher reward. It is one of the most important and influential economic theories dealing with finance and investment.

# %% [markdown]
# ## Monte Carlo Simulation for Optimization Search
#
# We could randomly try to find the optimal portfolio balance using Monte Carlo simulation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
aapl = pd.read_csv('AAPL_CLOSE.csv',index_col='Date',parse_dates=True)
cisco = pd.read_csv('CISCO_CLOSE.csv',index_col='Date',parse_dates=True)
ibm = pd.read_csv('IBM_CLOSE.csv',index_col='Date',parse_dates=True)
amzn = pd.read_csv('AMZN_CLOSE.csv',index_col='Date',parse_dates=True)

# %%
stocks = pd.concat([aapl,cisco,ibm,amzn],axis=1)
stocks.columns = ['aapl','cisco','ibm','amzn']

# %%
stocks.head()
# Out:
#                  aapl      cisco         ibm    amzn
# Date
# 2012-01-03  52.848787  15.617341  157.578371  179.03
# 2012-01-04  53.132802  15.919125  156.935540  177.51
# 2012-01-05  53.722681  15.860445  156.191208  177.61
# 2012-01-06  54.284287  15.801764  154.398046  182.61
# 2012-01-09  54.198183  15.902359  153.594506  178.56

# %%
mean_daily_ret = stocks.pct_change(1).mean()
mean_daily_ret
# Out:
# aapl     0.000864
# cisco    0.000738
# ibm      0.000045
# amzn     0.001528
# dtype: float64

# %%
stocks.pct_change(1).corr()
# Out:
#            aapl     cisco       ibm      amzn
# aapl   1.000000  0.317531  0.285458  0.268870
# cisco  0.317531  1.000000  0.418203  0.289248
# ibm    0.285458  0.418203  1.000000  0.246818
# amzn   0.268870  0.289248  0.246818  1.000000

# %%
stocks.head()
# Out:
#                  aapl      cisco         ibm    amzn
# Date
# 2012-01-03  52.848787  15.617341  157.578371  179.03
# 2012-01-04  53.132802  15.919125  156.935540  177.51
# 2012-01-05  53.722681  15.860445  156.191208  177.61
# 2012-01-06  54.284287  15.801764  154.398046  182.61
# 2012-01-09  54.198183  15.902359  153.594506  178.56

# %%
stock_normed = stocks/stocks.iloc[0]
stock_normed.plot(figsize=(12,8))

# %%
stock_daily_ret = stocks.pct_change(1)
stock_daily_ret.head()
# Out:
#                 aapl     cisco       ibm      amzn
# Date
# 2012-01-03       NaN       NaN       NaN       NaN
# 2012-01-04  0.005374  0.019324 -0.004079 -0.008490
# 2012-01-05  0.011102 -0.003686 -0.004743  0.000563
# 2012-01-06  0.010454 -0.003700 -0.011481  0.028152
# 2012-01-09 -0.001586  0.006366 -0.005204 -0.022178

# %% [markdown]
# ## Log Returns vs Arithmetic Returns
#
# Its better to switch over to using log returns instead of arithmetic returns, for many cases they are almost the same,but most technical analyses require detrending/normalizing the time series and using log returns is a better way to do that.
#
# Log returns are convenient to work with in many of the algorithms we encounter.

# %%
log_ret = np.log(stocks/stocks.shift(1))
log_ret.head()
# Out:
#                 aapl     cisco       ibm      amzn
# Date
# 2012-01-03       NaN       NaN       NaN       NaN
# 2012-01-04  0.005360  0.019139 -0.004088 -0.008526
# 2012-01-05  0.011041 -0.003693 -0.004754  0.000563
# 2012-01-06  0.010400 -0.003707 -0.011547  0.027763
# 2012-01-09 -0.001587  0.006346 -0.005218 -0.022428

# %%
log_ret.hist(bins=100,figsize=(12,8));
plt.tight_layout()

# %%
log_ret.describe().transpose()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# aapl   1564.0  0.000726  0.015745 -0.131875 -0.006695  0.000435  0.009118
# cisco  1566.0  0.000642  0.013826 -0.116091 -0.005786  0.000501  0.007373
# ibm    1566.0 -0.000023  0.011721 -0.086419 -0.005678  0.000108  0.006004
# amzn   1564.0  0.001356  0.018465 -0.116503 -0.007609  0.000935  0.010907
#
#             max
# aapl   0.085022
# cisco  0.118862
# ibm    0.084934
# amzn   0.146225

# %%
log_ret.mean()

# Gives the mean of the stocks in log form
# Out:
# aapl     0.000726
# cisco    0.000642
# ibm     -0.000023
# amzn     0.001356
# dtype: float64

# %%
# Compute pairwise covariance of columns
log_ret.cov()
# Out:
#            aapl     cisco       ibm      amzn
# aapl   0.000248  0.000069  0.000052  0.000078
# cisco  0.000069  0.000191  0.000068  0.000074
# ibm    0.000052  0.000068  0.000137  0.000054
# amzn   0.000078  0.000074  0.000054  0.000341

# %%
log_ret.cov()*252 

# multiply by days
# Out:
#            aapl     cisco       ibm      amzn
# aapl   0.062475  0.017422  0.013212  0.019764
# cisco  0.017422  0.048174  0.017071  0.018767
# ibm    0.013212  0.017071  0.034618  0.013552
# amzn   0.019764  0.018767  0.013552  0.085924

# %%
print(stocks.columns)

weights = np.array(np.random.random(4))
print(weights)

print('\n')

print('Rebalance to sum to 1.0')
weights = weights / np.sum(weights)
print(weights)
# Out:
# Index(['aapl', 'cisco', 'ibm', 'amzn'], dtype='object')
# [0.99875036 0.27918814 0.86986709 0.79166246]
#
#
# Rebalance to sum to 1.0
# [0.33977248 0.09497914 0.2959267  0.26932167]

# %%
# Expected Return
print('Expected Portfolio Return')
exp_ret = np.sum(log_ret.mean() * weights) *252
print(exp_ret)
# Out:
# Expected Portfolio Return
# 0.16782816828967506

# %%
# Expected Variance
print('Expected Volatility')
exp_vol = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
print(exp_vol)
# Out:
# Expected Volatility
# 0.16849173912505888

# %%
# Sharpe Ratio
SR = exp_ret/exp_vol
print('Sharpe Ratio')
print(SR)
# Out:
# Sharpe Ratio
# 0.968258346430954

# %% [markdown]
# Now we can just run this many times over!

# %%
num_ports = 15000

# the random port numbers can be higher or lower

all_weights = np.zeros((num_ports,len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for ind in range(num_ports):

    # Create Random Weights
    weights = np.array(np.random.random(4))

    # Rebalance Weights
    weights = weights / np.sum(weights)
    
    # Save Weights
    all_weights[ind,:] = weights

    # Expected Return
    ret_arr[ind] = np.sum((log_ret.mean() * weights) *252)

    # Expected Variance
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))

    # Sharpe Ratio
    sharpe_arr[ind] = ret_arr[ind]/vol_arr[ind]

# %%
sharpe_arr.max()
# Out:
# 1.2824284384778575

# %%
sharpe_arr.argmax()
# Gives the index location of the sharpe ratio
# Out:
# 2444

# %%
all_weights[2444,:]
# Out:
# array([0.21426034, 0.26294602, 0.00541084, 0.51738279])

# %%
max_sr_ret = ret_arr[2444]
max_sr_vol = vol_arr[2444]

# %% [markdown]
# ## Plotting the data

# %%
plt.figure(figsize=(12,8),dpi=100)
plt.scatter(vol_arr,ret_arr,c=sharpe_arr,cmap='plasma')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')

# Add red dot for max SR
plt.scatter(max_sr_vol,max_sr_ret,c='red',s=50,edgecolors='black')

# %% [markdown]
#  - **Based on random allocation, our optimal point seems to be at 20% volatility, the maximum returns will be 26%**

# %% [markdown]
# # Mathematical Optimization
#
# There are much better ways to find good allocation weights than just guess and check! We can use optimization functions to find the ideal weights mathematically!

# %% [markdown]
# ### Functionalize Return and SR operations

# %%
def get_ret_vol_sr(weights):
    
    weights = np.array(weights)
    ret = np.sum(log_ret.mean() * weights) * 252
    vol = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
    sr = ret/vol
    return np.array([ret,vol,sr])

# %%
from scipy.optimize import minimize

# %% [markdown]
# Optimization works as a minimization function, since we actually want to maximize the Sharpe Ratio, we will need to turn it negative so we can minimize the negative sharpe (same as maximizing the postive sharpe)

# %%
def neg_sharpe(weights):
    return  get_ret_vol_sr(weights)[2] * -1

# %%
# Contraints
def check_sum(weights):
    return np.sum(weights) - 1
# It will return 0 when the sum of weights is 1

# %%
cons = ({'type':'eq','fun': check_sum})

# %%
# 0-1 bounds for each weight
bounds = ((0, 1), (0, 1), (0, 1), (0, 1))

# %%
# Initial Guess (equal distribution)
init_guess = [0.25,0.25,0.25,0.25]

# %%
# Sequential Least SQuares Programming (SLSQP).
opt_results = minimize(neg_sharpe,init_guess,method='SLSQP',bounds=bounds,constraints=cons)

# %%
opt_results
# Out:
#      fun: -1.282847217101282
#      jac: array([-0.00072455, -0.00049016,  0.47258654,  0.00054568])
#  message: 'Optimization terminated successfully.'
#     nfev: 37
#      nit: 6
#     njev: 6
#   status: 0
#  success: True
#        x: array([2.29846244e-01, 2.44943656e-01, 3.76218154e-17, 5.25210100e-01])

# %%
opt_results.x
# Our actual allocation
# Out:
# array([2.29846244e-01, 2.44943656e-01, 3.76218154e-17, 5.25210100e-01])

# %%
get_ret_vol_sr(opt_results.x)

# The best sharpe ratio what we can get is 1.28
# Out:
# array([0.261193  , 0.20360414, 1.28284722])

# %% [markdown]
#  - **We notice that the results from optimization algorithm and the random guessing is almost close. This is because, we have only 4 stocks in our portfolio, if we have 100s of stocks,this might differ significantly.**

# %% [markdown]
# # All Optimal Portfolios (Efficient Frontier)
#
# The efficient frontier is the set of optimal portfolios that offers the highest expected return for a defined level of risk or the lowest risk for a given level of expected return.
#
# Portfolios that lie below the efficient frontier are sub-optimal, because they do not provide enough return for the level of risk.
#
# Portfolios that cluster to the right of the efficient frontier are also sub-optimal, because they have a higher level of risk for the defined rate of return.

# %%
# Our returns go from 0 to somewhere along 0.35
# Create a linspace number of points to calculate x on
frontier_y = np.linspace(0,0.35,100) # Change 100 to a lower number for slower computers!

# %%
def minimize_volatility(weights):
    return  get_ret_vol_sr(weights)[1]

# %%
frontier_volatility = []

for possible_return in frontier_y:
    # function for return
    cons = ({'type':'eq','fun': check_sum},
            {'type':'eq','fun': lambda w: get_ret_vol_sr(w)[0] - possible_return})
    
    result = minimize(minimize_volatility,init_guess,method='SLSQP',bounds=bounds,constraints=cons)
    
    frontier_volatility.append(result['fun'])

# %%
plt.figure(figsize=(12,8),dpi=100)
plt.scatter(vol_arr,ret_arr,c=sharpe_arr,cmap='plasma')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')



# Add frontier line
plt.plot(frontier_volatility,frontier_y,'g--',linewidth=3)

# %% [markdown]
#  - **The green frontier line represents the Maximum reurns possible from the volatility/Risk level. This based on historical data only and not forecasting.**
