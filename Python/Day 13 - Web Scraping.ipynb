# %% [markdown]
# # Web Scraping
# Web scraping is a technique to automatically access and extract large amounts of information from a website, which can save time and effort.

# %% [markdown]
# ## Basic components of a WebSite
#
# ### HTML
# HTML stands for Hypertext Markup Language and every website on the internet uses it to display information. The raw HTML page is the information that Python will be looking at to grab information. Let's take a look at a simple webpage's HTML:
#
#     <!DOCTYPE html>
#     <html>
#         <head>
#             <title>Title on Browser Tab</title>
#         </head>
#         <body>
#             <h1> Website Header </h1>
#             <p> Some Paragraph </p>
#         <body>
#     </html>

# %% [markdown]
# Every < > indicates a specific block type on the webpage:
#
#     1.<DOCTYPE html> HTML documents will always start with this type declaration, letting the browser know its an
#     HTML file.
#     2. The component blocks of the HTML document are placed between <html> and </html>.
#     3. Meta data and script connections (like a link to a CSS (Cascading style sheet) file or a JS (Java file)
#     are often placed in the <head> block.
#     4. The <title> tag defines the title of the webpage (its what shows up in the tab of a website).
#     5. Whatever is between <body> and </body> tags are the blocks that will be visible to the site visitor.
#     6. Headings are defined by the <h1> through <h6> tags, where the number represents the size of the heading.
#     7. Paragraphs are defined by the <p> tag, this is essentially just normal text on the website.
#
#     There are many more tags than just these, such as <a> for hyperlinks, <table> for tables, <tr> for table rows,
#     and <td> for table columns, and more!

# %% [markdown]
# ### CSS
#
# Cascading Style Sheets, this is what gives "style" to a website, including colors and fonts, and even some animations! CSS uses tags such as **id** or **class** to connect an HTML element to a CSS feature, such as a particular color. **id** is a unique id for an HTML tag and must be unique within the HTML document, basically a single use connection. **class** defines a general style that can then be linked to multiple HTML tags. Basically if you only want a single html tag to be red, you would use an id tag, if you wanted several HTML tags/blocks to be red, you would create a class in your CSS doc and then link it to the rest of these blocks.

# %% [markdown]
# #### Web Scraping tools in Python
#
# We need these libraries installed to proceed with web scraping
#
#     conda install requests
#     conda install lxml
#     conda install bs4

# %% [markdown]
# ## Gathering the data on Nuclear reactors in USA

# %%
res = requests.get("http://www.nrc.gov/reactors/operating/list-power-reactor-units.html")

# %%
res.status_code
# Out:
# 200

# %% [markdown]
# We got this output hence, we were successful in accessing the webpage

# %%
title = 'http://www.nrc.gov/reactors/operating/list-power-reactor-units.html'

# %% [markdown]
# Now we use BeautifulSoup to analyze the extracted page. Technically we could use our own custom script to loook for items in the string of **res.text** but the BeautifulSoup library already has lots of built-in tools and methods to grab information from a string of this nature (a HTML file). Using BeautifulSoup we can create a "soup" object that contains all the "ingredients" of the webpage.

# %% [markdown]
# We use the **.select( )** method to grab elements. We are looking for the 'title' tag, so we will pass in 'title'

# %%
soup.select('title')
# Out:
# [<title>NRC: List of Power Reactor Units</title>]

# %%
import pandas as pd
import requests

from bs4 import BeautifulSoup

# %%
url = "http://www.nrc.gov/reactors/operating/list-power-reactor-units.html"
main_page = requests.get(url)

# %%
soup = BeautifulSoup(main_page.content, 'html.parser')

# %%
# snip out the table and pass it to a new variable
reactors_table = soup.find('table')

# %%
# print reactor_table to verify we have the right thing
print(reactors_table)
# Out:
# <table border="1" cellpadding="5" cellspacing="0" summary="List of Power Reactor Units" width="100%">
# <tr valign="top">
# <th scope="col">Plant Name<br/>
# Docket Number</th>
# <th scope="col">License Number</th>
# <th scope="col">Reactor<br/>
# Type</th>
# <th scope="col">Location</th>
# <th scope="col">Owner/Operator</th>
# <th scope="col">NRC Region</th>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors
>
# <td align="middle">1</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/susq2.html">Susquehanna 2</a><br/>05000388</td>
# <td align="center">NPF-22</td>
# <td>BWR</td>
# <td>70 miles NE of Harrisburg,  PA</td>
# <td>Susquehanna Nuclear,  LLC</td>
# <td align="middle">1</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/tmi1.html">Three Mile Island 1</a><br/>05000289</td>
# <td align="center">DPR-50</td>
# <td>PWR</td>
# <td>10 miles SE of Harrisburg,  PA</td>
# <td>Exelon Generation Co., LLC</td>
# <td align="middle">1</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/tp3.html">Turkey Point 3</a><br/>05000250</td>
# <td align="center">DPR-31</td>
# <td>PWR</td>
# <td>20 miles S of Miami,  FL</td>
# <td>Florida Power &amp; Light Co. </td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/tp4.html">Turkey Point 4</a><br/>05000251</td>
# <td align="center">DPR-41</td>
# <td>PWR</td>
# <td>20 miles S of Miami,  FL</td>
# <td>Florida Power &amp; Light Co. </td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/vog1.html">Vogtle 1</a><br/>05000424</td>
# <td align="center">NPF-68</td>
# <td>PWR</td>
# <td>26 miles SE of Augusta,  GA</td>
# <td>Southern Nuclear Operating Co.</td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/vog2.html">Vogtle 2</a><br/>05000425</td>
# <td align="center">NPF-81</td>
# <td>PWR</td>
# <td>26 miles SE of Augusta,  GA</td>
# <td>Southern Nuclear Operating Co.</td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/wat3.html">Waterford 3</a><br/>05000382</td>
# <td align="center">NPF-38</td>
# <td>PWR</td>
# <td>25 miles W of New Orleans,  LA</td>
# <td>Entergy Nuclear Operations, Inc.</td>
# <td align="middle">4</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/wb1.html">Watts Bar 1</a><br/>05000390</td>
# <td align="center">NPF-90</td>
# <td>PWR</td>
# <td>60 miles SW of Knoxville,  TN</td>
# <td>Tennessee Valley Authority </td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/wb2.html">Watts Bar 2</a><br/>05000391</td>
# <td align="center">NPF-96</td>
# <td>PWR</td>
# <td>60 miles SW of Knoxville,  TN</td>
# <td>Tennessee Valley Authority </td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/wc.html">Wolf Creek 1</a><br/>05000482</td>
# <td align="center">NPF-42</td>
# <td>PWR</td>
# <td>3.5 miles NE of Burlington,  KS</td>
# <td>Wolf Creek Nuclear Operating Corp. </td>
# <td align="middle">4</td>
# </tr>
# </table>

# %%
# use .find_all to create a list of rows in the table
reactor_rows = reactors_table.find_all('tr')

# %%
# isolate the fourth row and print it
ex_row = reactor_rows[3]
print(ex_row)
# Out:
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/bv1.html">Beaver Valley 1</a><br/>05000334</td>
# <td align="center">DPR-66</td>
# <td>PWR</td>
# <td>17 miles W of McCandless,  PA</td>
# <td>FirstEnergy Nuclear Operating Co. </td>
# <td align="middle">1</td>
# </tr>

# %%
# use .find_all again to generate a list of the row's cells and return it
cells = ex_row.find_all('td')
cells
# Out:
# [<td scope="row"><a href="/info-finder/reactors/bv1.html">Beaver Valley 1</a><br/>05000334</td>,
#  <td align="center">DPR-66</td>,
#  <td>PWR</td>,
#  <td>17 miles W of McCandless,  PA</td>,
#  <td>FirstEnergy Nuclear Operating Co. </td>,
#  <td align="middle">1</td>]

# %%
# examine the "contents" of the first item in cells
cells[0].contents
# Out:
# [<a href="/info-finder/reactors/bv1.html">Beaver Valley 1</a>,
#  <br/>,
#  '05000334']

# %%
# isolate and print the name, the link and the docket number
print(cells[0].contents[0].text)
print(cells[0].contents[0].get('href'))
print(cells[0].contents[2])
# Out:
# Beaver Valley 1
# /info-finder/reactors/bv1.html
# 05000334

# %%
scraped_data = []
for row in reactors_table.find_all('tr')[1:]:
    
    # .find_all 'td' tags in the row and put them into a variable
    cells = row.find_all('td')
    
    # extract the cell contents
    reactor_name = cells[0].contents[0].text
    link = 'http://www.nrc.gov' + cells[0].contents[0].get('href')
    docket = cells[0].contents[2]
    license = cells[1].text
    reactor_type = cells[2].text
    location = cells[3].text
    owner = cells[4].text
    region = cells[5].text
    
    # append the collected data to the empty list
    scraped_data.append([reactor_name, link, docket, license, reactor_type, location, owner, region])

# %%
scraped_data
# Out:
# [['Arkansas Nuclear 1',
#   'http://www.nrc.gov/info-finder/reactors/ano1.html',
#   '05000313',
#   'DPR-51',
#   'PWR',
#   '6 miles WNW of Russellville,\xa0\xa0AR',
#   'Entergy Nuclear Operations, Inc. ',
#   '4'],
#  ['Arkansas Nuclear 2',
#   'http://www.nrc.gov/info-finder/reactors/ano2.html',
#   '05000368',
#   'NPF-6',
#   'PWR',
#   '6 miles WNW of Russellville,\xa0\xa0AR',
#   'Entergy Nuclear Operations, Inc. ',
#   '4'],
#  ['Beaver Valley 1',
#   'http://www.nrc.gov/info-finder/reactors/bv1.html',
#   '05000334',
#   'DPR-66',
#   'PWR',
#   '17 miles W of McCandless,\xa0\xa0PA',
#   'FirstEnergy Nuclear Operating Co. ',
#   '1'],
#  ['Beaver Valley 2',
#   'http://www.nrc.gov/info-finder/reactors/bv2.html',
#   '05000412',
#   'NPF-73',
#   'PWR',
#   '17 miles W of McCandless,\xa0\xa0PA',
#   'FirstEnergy Nuclear Operating Co. ',
#   '1'],
#  ['Braidwood 1',
#   'http://www.nrc.gov/info-finder/reactors/brai1.html',
#   '05000456',
#   'NPF-72',
#   'PWR',
#   '20 miles SSW of Joliet,\xa0\xa0IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['Braidwood 2',
#   'http://www.nrc.gov/info-finder/reactors/brai2.html',
#   '05000457',
#   'NPF-77',
#   'PWR',
#   '20 miles SSW of Joliet,\xa0\xa0IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['Browns Ferry 1',
#   'http://www.nrc.gov/info-finder/reactors/bf1.html',
#   '05000259',
#   'DPR-33',
#   'BWR',
#   '32 miles W of Huntsville,  AL',
#   'Tennessee Valley Authority ',
#   '2'],
#  ['Browns Ferry 2',
#   'http://www.nrc.gov/info-finder/reactors/bf2.html',
#   '05000260',
#   'DPR-52',
#   'BWR',
#   '32 miles W of Huntsville,  AL',
#   'Tennessee Valley Authority ',
#   '2'],
#  ['Browns Ferry 3',
#   'http://www.nrc.gov/info-finder/reactors/bf3.html',
#   '05000296',
#   'DPR-68',
#   'BWR',
#   '32 miles W of Huntsville,  AL',
#   'Tennessee Valley Authority ',
#   '2'],
#  ['Brunswick 1',
#   'http://www.nrc.gov/info-finder/reactors/bru1.html',
#   '05000325',
#   'DPR-71',
#   'BWR',
#   '30 miles S of Wilmington,  NC',
#   'Duke Energy Progress, LLC ',
#   '2'],
#  ['Brunswick 2',
#   'http://www.nrc.gov/info-finder/reactors/bru2.html',
#   '05000324',
#   'DPR-62',
#   'BWR',
#   '30 miles S of Wilmington,  NC',
#   'Duke Energy Progress, LLC',
#   '2'],
#  ['Byron 1',
#   'http://www.nrc.gov/info-finder/reactors/byro1.html',
#   '05000454',
#   'NPF-37',
#   'PWR',
#   '17 miles SW of Rockford,\xa0\xa0IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['Byron 2',
#   'http://www.nrc.gov/info-finder/reactors/byro2.html',
#   '05000455',
#   'NPF-66',
#   'PWR',
#   '17 miles SW of Rockford,\xa0\xa0IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['Callaway',
#   'http://www.nrc.gov/info-finder/reactors/call.html',
#   '05000483',
#   'NPF-30',
#   'PWR',
#   '25 miles ENE of Jefferson  City, MO',
#   'Ameren UE ',
#   '4'],
#  ['Calvert Cliffs 1',
#   'http://www.nrc.gov/info-finder/reactors/calv1.html',
#   '05000317',
#   'DPR-53',
#   'PWR',
#   '40 miles S of Annapolis,\xa0\xa0MD',
#   'Constellation Energy',
#   '1'],
#  ['Calvert Cliffs 2',
#   'http://www.nrc.gov/info-finder/reactors/calv2.html',
#   '05000318',
#   'DPR-69',
#   'PWR',
#   '40 miles S of Annapolis,\xa0\xa0MD',
#   'Constellation Energy',
#   '1'],
#  ['Catawba 1',
#   'http://www.nrc.gov/info-finder/reactors/cat1.html',
#   '05000413',
#   'NPF-35',
#   'PWR',
#   '18 miles S of Charlotte, NC',
#   'Duke Energy Carolinas, LLC ',
#   '2'],
#  ['Catawba 2',
#   'http://www.nrc.gov/info-finder/reactors/cat2.html',
#   '05000414',
#   'NPF-52',
#   'PWR',
#   '18 miles S of Charlotte, NC',
#   'Duke Energy Carolinas, LLC',
#   '2'],
#  ['Clinton',
#   'http://www.nrc.gov/info-finder/reactors/clin.html',
#   '05000461',
#   'NPF-62',
#   'BWR',
#   '23 miles SSE of  Bloomington, IL',
#   'Exelon Generation Co., LLC',
#   '3'],
#  ['Columbia Generating Station',
#   'http://www.nrc.gov/info-finder/reactors/wash2.html',
#   '05000397',
#   'NPF-21',
#   'BWR',
#   '20 miles NNE of Pasco, WA',
#   'Energy Northwest ',
#   '4'],
#  ['Comanche Peak 1',
#   'http://www.nrc.gov/info-finder/reactors/cp1.html',
#   '05000445',
#   'NPF-87',
#   'PWR',
#   '40 miles SW of Fort Worth,  TX',
#   'TEX Operations Company LLC',
#   '4'],
#  ['Comanche Peak 2',
#   'http://www.nrc.gov/info-finder/reactors/cp2.html',
#   '05000446',
#   'NPF-89',
#   'PWR',
#   '40 miles SW of Fort Worth,  TX',
#   'TEX Operations Company LLC',
#   '4'],
#  ['Cooper',
#   'http://www.nrc.gov/info-finder/reactors/cns.html',
#   '05000298',
#   'DPR-46',
#   'BWR',
#   '23 miles S of Nebraska City,\xa0\xa0NE',
#   'Nebraska Public Power District ',
#   '4'],
#  ['D.C. Cook 1',
#   'http://www.nrc.gov/info-finder/reactors/cook1.html',
#   '05000315',
#   'DPR-58',
#   'PWR',
#   '13 miles S of Benton Harbor,\xa0\xa0MI',
#   'Indiana/Michigan Power Co. ',
#   '3'],
#  ['D.C. Cook 2 ',
#   'http://www.nrc.gov/info-finder/reactors/cook2.html',
#   '05000316',
#   'DPR-74',
#   'PWR',
#   '13 miles S of Benton Harbor,\xa0\xa0MI',
#   'Indiana/Michigan Power Co. ',
#   '3'],
#  ['Davis-Besse',
#   'http://www.nrc.gov/info-finder/reactors/davi.html',
#   '05000346',
#   'NPF-3',
#   'PWR',
#   '21 miles ESE of Toledo,\xa0\xa0OH',
#   'FirstEnergy Nuclear Operating Co. ',
#   '3'],
#  ['Diablo Canyon 1',
#   'http://www.nrc.gov/info-finder/reactors/diab1.html',
#   '05000275',
#   'DPR-80',
#   'PWR',
#   '12 miles WSW of San Luis Obispo,\xa0\xa0CA',
#   'Pacific Gas & Electric Co. ',
#   '4'],
#  ['Diablo Canyon 2',
#   'http://www.nrc.gov/info-finder/reactors/diab2.html',
#   '05000323',
#   'DPR-82',
#   'PWR',
#   '12 miles WSW of San Luis Obispo,\xa0\xa0CA',
#   'Pacific Gas & Electric Co. ',
#   '4'],
#  ['Dresden 2',
#   'http://www.nrc.gov/info-finder/reactors/dres2.html',
#   '05000237',
#   'DPR-19',
#   'BWR',
#   '25 miles SW of Joliet, IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['Dresden 3',
#   'http://www.nrc.gov/info-finder/reactors/dres3.html',
#   '05000249',
#   'DPR-25',
#   'BWR',
#   '25 miles SW of Joliet, IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['Duane Arnold',
#   'http://www.nrc.gov/info-finder/reactors/duan.html',
#   '05000331',
#   'DPR-49',
#   'BWR',
#   '8 miles NW of Cedar Rapids,\xa0\xa0IA',
#   'NextEra Energy Duane Arnold, LLC ',
#   '3'],
#  ['Farley 1',
#   'http://www.nrc.gov/info-finder/reactors/far1.html',
#   '05000348',
#   'NPF-2',
#   'PWR',
#   '18 miles E of Dothan,\xa0\xa0AL',
#   'Southern Nuclear Operating Co. ',
#   '2'],
#  ['Farley 2',
#   'http://www.nrc.gov/info-finder/reactors/far2.html',
#   '05000364',
#   'NPF-8',
#   'PWR',
#   '18 miles E of Dothan,\xa0\xa0AL',
#   'Southern Nuclear Operating Co.',
#   '2'],
#  ['Fermi 2',
#   'http://www.nrc.gov/info-finder/reactors/ferm2.html',
#   '05000341',
#   'NPF-43',
#   'BWR',
#   '25 miles NE of Toledo,\xa0\xa0OH',
#   'DTE Electric Company',
#   '3'],
#  ['FitzPatrick',
#   'http://www.nrc.gov/info-finder/reactors/fitz.html',
#   '05000333',
#   'DPR-59',
#   'BWR',
#   '6 miles NE of Oswego,\xa0\xa0NY',
#   'Exelon FitzPatrick, LLC/Exelon Generation Company, LLC',
#   '1'],
#  ['Ginna',
#   'http://www.nrc.gov/info-finder/reactors/ginn.html',
#   '05000244',
#   'DPR-18',
#   'PWR',
#   '20 miles NE of Rochester,\xa0\xa0NY',
#   'Constellation Energy',
#   '1'],
#  ['Grand Gulf 1',
#   'http://www.nrc.gov/info-finder/reactors/gg1.html',
#   '05000416',
#   'NPF-29',
#   'BWR',
#   '20 miles S of Vicksburg,\xa0\xa0MS',
#   'Entergy Nuclear Operations, Inc.',
#   '4'],
#  ['Hatch 1',
#   'http://www.nrc.gov/info-finder/reactors/hat1.html',
#   '05000321',
#   'DPR-57',
#   'BWR',
#   '20 miles S of Vidalia, GA',
#   'Southern Nuclear Operating Co., Inc. ',
#   '2'],
#  ['Hatch 2',
#   'http://www.nrc.gov/info-finder/reactors/hat2.html',
#   '05000366',
#   'NPF-5',
#   'BWR',
#   '20 miles S of Vidalia, GA',
#   'Southern Nuclear Operating Co., Inc. ',
#   '2'],
#  ['Hope Creek 1',
#   'http://www.nrc.gov/info-finder/reactors/hope.html',
#   '05000354',
#   'NPF-57',
#   'BWR',
#   '18 miles SE of Wilmington,\xa0\xa0DE',
#   'PSEG Nuclear, LLC',
#   '1'],
#  ['Indian Point 2',
#   'http://www.nrc.gov/info-finder/reactors/ip2.html',
#   '05000247',
#   'DPR-26',
#   'PWR',
#   '24 miles N of New York City,\xa0\xa0NY',
#   'Entergy Nuclear Operations, Inc.',
#   '1'],
#  ['Indian Point 3',
#   'http://www.nrc.gov/info-finder/reactors/ip3.html',
#   '05000286',
#   'DPR-64',
#   'PWR',
#   '24 miles N of New York City,\xa0\xa0NY',
#   'Entergy Nuclear Operations, Inc.',
#   '1'],
#  ['La Salle 1',
#   'http://www.nrc.gov/info-finder/reactors/lasa1.html',
#   '05000373',
#   'NPF-11',
#   'BWR',
#   '11 miles SE of Ottawa,\xa0\xa0IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['La Salle 2',
#   'http://www.nrc.gov/info-finder/reactors/lasa2.html',
#   '05000374',
#   'NPF-18',
#   'BWR',
#   '11 miles SE of Ottawa,\xa0\xa0IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['Limerick 1',
#   'http://www.nrc.gov/info-finder/reactors/lim1.html',
#   '05000352',
#   'NPF-39',
#   'BWR',
#   '21 miles NW of Philadelphia,\xa0\xa0PA',
#   'Exelon Generation Co., LLC ',
#   '1'],
#  ['Limerick 2',
#   'http://www.nrc.gov/info-finder/reactors/lim2.html',
#   '05000353',
#   'NPF-85',
#   'BWR',
#   '21 miles NW of Philadelphia,\xa0\xa0PA',
#   'Exelon Generation Co., LLC ',
#   '1'],
#  ['McGuire 1',
#   'http://www.nrc.gov/info-finder/reactors/mcg1.html',
#   '05000369',
#   'NPF-9',
#   'PWR',
#   '17 miles N of Charlotte,\xa0\xa0NC',
#   'Duke Energy Carolinas, LLC',
#   '2'],
#  ['McGuire 2',
#   'http://www.nrc.gov/info-finder/reactors/mcg2.html',
#   '05000370',
#   'NPF-17',
#   'PWR',
#   '17 miles N of Charlotte,\xa0\xa0NC',
#   'Duke Energy Carolinas, LLC',
#   '2'],
#  ['Millstone 2',
#   'http://www.nrc.gov/info-finder/reactors/mill2.html',
#   '05000336',
#   'DPR-65',
#   'PWR',
#   '3.2 miles WSW of New London,\xa0\xa0CT',
#   'Dominion Generation ',
#   '1'],
#  ['Millstone 3',
#   'http://www.nrc.gov/info-finder/reactors/mill3.html',
#   '05000423',
#   'NPF-49',
#   'PWR',
#   '3.2 miles WSW of New London,\xa0\xa0CT',
#   'Dominion Generation ',
#   '1'],
#  ['Monticello',
#   'http://www.nrc.gov/info-finder/reactors/mont.html',
#   '05000263',
#   'DPR-22',
#   'BWR',
#   '35 miles NW of Minneapolis,\xa0\xa0MN',
#   'Northern States Power Company – Minnesota',
#   '3'],
#  ['Nine Mile Point 1',
#   'http://www.nrc.gov/info-finder/reactors/nmp1.html',
#   '05000220',
#   'DPR-63',
#   'BWR',
#   '6 miles NE of Oswego,\xa0\xa0NY',
#   'Constellation Energy',
#   '1'],
#  ['Nine Mile Point 2',
#   'http://www.nrc.gov/info-finder/reactors/nmp2.html',
#   '05000410',
#   'NPF-69',
#   'BWR',
#   '6 miles NE of Oswego,\xa0\xa0NY',
#   'Constellation Energy',
#   '1'],
#  ['North Anna 1',
#   'http://www.nrc.gov/info-finder/reactors/na1.html',
#   '05000338',
#   'NPF-4',
#   'PWR',
#   '40 miles NW of Richmond,\xa0\xa0VA',
#   'Dominion Generation',
#   '2'],
#  ['North Anna 2',
#   'http://www.nrc.gov/info-finder/reactors/na2.html',
#   '05000339',
#   'NPF-7',
#   'PWR',
#   '40 miles NW of Richmond,\xa0\xa0VA',
#   'Dominion Generation',
#   '2'],
#  ['Oconee 1',
#   'http://www.nrc.gov/info-finder/reactors/oco1.html',
#   '05000269',
#   'DPR-38',
#   'PWR',
#   '30 miles W of Greenville,\xa0\xa0SC',
#   'Duke Energy Carolinas, LLC',
#   '2'],
#  ['Oconee 2',
#   'http://www.nrc.gov/info-finder/reactors/oco2.html',
#   '05000270',
#   'DPR-47',
#   'PWR',
#   '30 miles W of Greenville,\xa0\xa0SC',
#   'Duke Energy Carolinas, LLC',
#   '2'],
#  ['Oconee 3',
#   'http://www.nrc.gov/info-finder/reactors/oco3.html',
#   '05000287',
#   'DPR-55',
#   'PWR',
#   '30 miles W of Greenville,\xa0\xa0SC',
#   'Duke Energy Carolinas, LLC',
#   '2'],
#  ['Oyster Creek',
#   'http://www.nrc.gov/info-finder/reactors/oc.html',
#   '05000219',
#   'DPR-16',
#   'BWR',
#   '9 miles S of Toms River,\xa0\xa0NJ',
#   'Exelon Generation Co., LLC',
#   '1'],
#  ['Palisades',
#   'http://www.nrc.gov/info-finder/reactors/pali.html',
#   '05000255',
#   'DPR-20',
#   'PWR',
#   '5 miles S of South Haven,\xa0\xa0MI',
#   'Entergy Nuclear Operations, Inc.',
#   '3'],
#  ['Palo Verde 1',
#   'http://www.nrc.gov/info-finder/reactors/palo1.html',
#   '05000528',
#   'NPF-41',
#   'PWR',
#   '50 miles W of Phoenix,\xa0\xa0AZ',
#   'Arizona Public Service Co. ',
#   '4'],
#  ['Palo Verde 2',
#   'http://www.nrc.gov/info-finder/reactors/palo2.html',
#   '05000529',
#   'NPF-51',
#   'PWR',
#   '50 miles W of Phoenix,\xa0\xa0AZ',
#   'Arizona Public Service Co. ',
#   '4'],
#  ['Palo Verde 3',
#   'http://www.nrc.gov/info-finder/reactors/palo3.html',
#   '05000530',
#   'NPF-74',
#   'PWR',
#   '50 miles W of Phoenix,\xa0\xa0AZ',
#   'Arizona Public Service Co. ',
#   '4'],
#  ['Peach Bottom 2',
#   'http://www.nrc.gov/info-finder/reactors/pb2.html',
#   '05000277',
#   'DPR-44',
#   'BWR',
#   '17.9 miles S of Lancaster,\xa0\xa0PA',
#   'Exelon Generation Co., LLC ',
#   '1'],
#  ['Peach Bottom 3',
#   'http://www.nrc.gov/info-finder/reactors/pb3.html',
#   '05000278',
#   'DPR-56',
#   'BWR',
#   '17.9 miles S of Lancaster,\xa0\xa0PA',
#   'Exelon Generation Co., LLC ',
#   '1'],
#  ['Perry 1',
#   'http://www.nrc.gov/info-finder/reactors/perr1.html',
#   '05000440',
#   'NPF-58',
#   'BWR',
#   '35 miles NE of Cleveland,  OH',
#   'FirstEnergy Nuclear Operating Co. ',
#   '3'],
#  ['Pilgrim 1',
#   'http://www.nrc.gov/info-finder/reactors/pilg.html',
#   '05000293',
#   'DPR-35',
#   'BWR',
#   '38 miles SE of Boston, MA',
#   'Entergy Nuclear Operations, Inc.',
#   '1'],
#  ['Point Beach 1',
#   'http://www.nrc.gov/info-finder/reactors/poin1.html',
#   '05000266',
#   'DPR-24',
#   'PWR',
#   '13 miles NNW of Manitowoc,\xa0\xa0WI',
#   'NextEra Energy Point Beach, LLC',
#   '3'],
#  ['Point Beach 2',
#   'http://www.nrc.gov/info-finder/reactors/poin2.html',
#   '05000301',
#   'DPR-27',
#   'PWR',
#   '13 miles NNW of Manitowoc,\xa0\xa0WI',
#   'NextEra Energy Point Beach, LLC',
#   '3'],
#  ['Prairie Island 1',
#   'http://www.nrc.gov/info-finder/reactors/prai1.html',
#   '05000282',
#   'DPR-42',
#   'PWR',
#   '28 miles SE of Minneapolis,\xa0\xa0MN',
#   'Northern States Power Company – Minnesota ',
#   '3'],
#  ['Prairie Island 2',
#   'http://www.nrc.gov/info-finder/reactors/prai2.html',
#   '05000306',
#   'DPR-60',
#   'PWR',
#   '28 miles SE of Minneapolis,\xa0\xa0MN',
#   'Northern States Power Company – Minnesota ',
#   '3'],
#  ['Quad Cities 1',
#   'http://www.nrc.gov/info-finder/reactors/quad1.html',
#   '05000254',
#   'DPR-29',
#   'BWR',
#   '20 miles NE of Moline,\xa0\xa0IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['Quad Cities 2',
#   'http://www.nrc.gov/info-finder/reactors/quad2.html',
#   '05000265',
#   'DPR-30',
#   'BWR',
#   '20 miles NE of Moline,\xa0\xa0IL',
#   'Exelon Generation Co., LLC ',
#   '3'],
#  ['River Bend 1',
#   'http://www.nrc.gov/info-finder/reactors/rbs1.html',
#   '05000458',
#   'NPF-47',
#   'BWR',
#   '24 miles NNW of Baton Rouge,\xa0\xa0LA',
#   'Entergy Nuclear Operations, Inc.',
#   '4'],
#  ['Robinson 2',
#   'http://www.nrc.gov/info-finder/reactors/rob2.html',
#   '05000261',
#   'DPR-23',
#   'PWR',
#   '26 miles NW of Florence,\xa0\xa0SC',
#   'Duke Energy Progress, LLC ',
#   '2'],
#  ['Saint Lucie 1',
#   'http://www.nrc.gov/info-finder/reactors/stl1.html',
#   '05000335',
#   'DPR-67',
#   'PWR',
#   '10 miles SE of Ft. Pierce,\xa0\xa0FL',
#   'Florida Power & Light Co. ',
#   '2'],
#  ['Saint Lucie 2',
#   'http://www.nrc.gov/info-finder/reactors/stl2.html',
#   '05000389',
#   'NPF-16',
#   'PWR',
#   '10 miles SE of Ft. Pierce,\xa0\xa0FL',
#   'Florida Power & Light Co. ',
#   '2'],
#  ['Salem 1',
#   'http://www.nrc.gov/info-finder/reactors/salm1.html',
#   '05000272',
#   'DPR-70',
#   'PWR',
#   '18 miles S of Wilmington,\xa0\xa0DE',
#   'PSEG Nuclear, LLC',
#   '1'],
#  ['Salem 2',
#   'http://www.nrc.gov/info-finder/reactors/salm2.html',
#   '05000311',
#   'DPR-75',
#   'PWR',
#   '18 miles S of Wilmington,\xa0\xa0DE',
#   'PSEG Nuclear, LLC',
#   '1'],
#  ['Seabrook 1',
#   'http://www.nrc.gov/info-finder/reactors/seab1.html',
#   '05000443',
#   'NPF-86',
#   'PWR',
#   '13 miles S of Portsmouth,\xa0\xa0NH',
#   'NextEra Energy Seabrook, LLC',
#   '1'],
#  ['Sequoyah 1',
#   'http://www.nrc.gov/info-finder/reactors/seq1.html',
#   '05000327',
#   'DPR-77',
#   'PWR',
#   '16 miles NE of Chattanooga,\xa0\xa0TN',
#   'Tennessee Valley Authority ',
#   '2'],
#  ['Sequoyah 2',
#   'http://www.nrc.gov/info-finder/reactors/seq2.html',
#   '05000328',
#   'DPR-79',
#   'PWR',
#   '16 miles NE of Chattanooga,\xa0\xa0TN',
#   'Tennessee Valley Authority ',
#   '2'],
#  ['Shearon Harris 1',
#   'http://www.nrc.gov/info-finder/reactors/har1.html',
#   '05000400',
#   'NPF-63',
#   'PWR',
#   '20 miles SW of Raleigh,\xa0\xa0NC',
#   'Duke Energy Progress, LLC',
#   '2'],
#  ['South Texas 1',
#   'http://www.nrc.gov/info-finder/reactors/stp1.html',
#   '05000498',
#   'NPF-76',
#   'PWR',
#   '90 miles SW of Houston, TX',
#   'STP Nuclear Operating Co. ',
#   '4'],
#  ['South Texas 2',
#   'http://www.nrc.gov/info-finder/reactors/stp2.html',
#   '05000499',
#   'NPF-80',
#   'PWR',
#   '90 miles SW of Houston, TX',
#   'STP Nuclear Operating Co. ',
#   '4'],
#  ['Summer',
#   'http://www.nrc.gov/info-finder/reactors/sum.html',
#   '05000395',
#   'NPF-12',
#   'PWR',
#   '26 miles NW of Columbia,\xa0\xa0SC',
#   'South Carolina Electric & Gas Co. ',
#   '2'],
#  ['Surry 1',
#   'http://www.nrc.gov/info-finder/reactors/sur1.html',
#   '05000280',
#   'DPR-32',
#   'PWR',
#   '17 miles NW of Newport News,\xa0\xa0VA',
#   'Dominion Generation',
#   '2'],
#  ['Surry 2',
#   'http://www.nrc.gov/info-finder/reactors/sur2.html',
#   '05000281',
#   'DPR-37',
#   'PWR',
#   '17 miles NW of Newport News,\xa0\xa0VA',
#   'Dominion Generation',
#   '2'],
#  ['Susquehanna 1',
#   'http://www.nrc.gov/info-finder/reactors/susq1.html',
#   '05000387',
#   'NPF-14',
#   'BWR',
#   '70 miles NE of Harrisburg,  PA',
#   'Susquehanna Nuclear,  LLC',
#   '1'],
#  ['Susquehanna 2',
#   'http://www.nrc.gov/info-finder/reactors/susq2.html',
#   '05000388',
#   'NPF-22',
#   'BWR',
#   '70 miles NE of Harrisburg,  PA',
#   'Susquehanna Nuclear,  LLC',
#   '1'],
#  ['Three Mile Island 1',
#   'http://www.nrc.gov/info-finder/reactors/tmi1.html',
#   '05000289',
#   'DPR-50',
#   'PWR',
#   '10 miles SE of Harrisburg,\xa0\xa0PA',
#   'Exelon Generation Co., LLC',
#   '1'],
#  ['Turkey Point 3',
#   'http://www.nrc.gov/info-finder/reactors/tp3.html',
#   '05000250',
#   'DPR-31',
#   'PWR',
#   '20 miles S of Miami,\xa0\xa0FL',
#   'Florida Power & Light Co. ',
#   '2'],
#  ['Turkey Point 4',
#   'http://www.nrc.gov/info-finder/reactors/tp4.html',
#   '05000251',
#   'DPR-41',
#   'PWR',
#   '20 miles S of Miami,\xa0\xa0FL',
#   'Florida Power & Light Co. ',
#   '2'],
#  ['Vogtle 1',
#   'http://www.nrc.gov/info-finder/reactors/vog1.html',
#   '05000424',
#   'NPF-68',
#   'PWR',
#   '26 miles SE of Augusta,\xa0\xa0GA',
#   'Southern Nuclear Operating Co.',
#   '2'],
#  ['Vogtle 2',
#   'http://www.nrc.gov/info-finder/reactors/vog2.html',
#   '05000425',
#   'NPF-81',
#   'PWR',
#   '26 miles SE of Augusta,\xa0\xa0GA',
#   'Southern Nuclear Operating Co.',
#   '2'],
#  ['Waterford 3',
#   'http://www.nrc.gov/info-finder/reactors/wat3.html',
#   '05000382',
#   'NPF-38',
#   'PWR',
#   '25 miles W of New Orleans,\xa0\xa0LA',
#   'Entergy Nuclear Operations, Inc.',
#   '4'],
#  ['Watts Bar 1',
#   'http://www.nrc.gov/info-finder/reactors/wb1.html',
#   '05000390',
#   'NPF-90',
#   'PWR',
#   '60 miles SW of Knoxville,  TN',
#   'Tennessee Valley Authority ',
#   '2'],
#  ['Watts Bar 2',
#   'http://www.nrc.gov/info-finder/reactors/wb2.html',
#   '05000391',
#   'NPF-96',
#   'PWR',
#   '60 miles SW of Knoxville,  TN',
#   'Tennessee Valley Authority ',
#   '2'],
#  ['Wolf Creek 1',
#   'http://www.nrc.gov/info-finder/reactors/wc.html',
#   '05000482',
#   'NPF-42',
#   'PWR',
#   '3.5 miles NE of Burlington,\xa0\xa0KS',
#   'Wolf Creek Nuclear Operating Corp. ',
#   '4']]

# %%
import pandas as pd
df = pd.DataFrame(scraped_data)
df.head(12)
# Out:
#                      0                                                  1  \
# 0   Arkansas Nuclear 1  http://www.nrc.gov/info-finder/reactors/ano1.html
# 1   Arkansas Nuclear 2  http://www.nrc.gov/info-finder/reactors/ano2.html
# 2      Beaver Valley 1   http://www.nrc.gov/info-finder/reactors/bv1.html
# 3      Beaver Valley 2   http://www.nrc.gov/info-finder/reactors/bv2.html
# 4          Braidwood 1  http://www.nrc.gov/info-finder/reactors/brai1....
# 5          Braidwood 2  http://www.nrc.gov/info-finder/reactors/brai2....
# 6       Browns Ferry 1   http://www.nrc.gov/info-finder/reactors/bf1.html
# 7       Browns Ferry 2   http://www.nrc.gov/info-finder/reactors/bf2.html
# 8       Browns Ferry 3   http://www.nrc.gov/info-finder/reactors/bf3.html
# 9          Brunswick 1  http://www.nrc.gov/info-finder/reactors/bru1.html
# 10         Brunswick 2  http://www.nrc.gov/info-finder/reactors/bru2.html
# 11             Byron 1  http://www.nrc.gov/info-finder/reactors/byro1....
#
#            2       3    4                                 5  \
# 0   05000313  DPR-51  PWR  6 miles WNW of Russellville,  AR
# 1   05000368   NPF-6  PWR  6 miles WNW of Russellville,  AR
# 2   05000334  DPR-66  PWR     17 miles W of McCandless,  PA
# 3   05000412  NPF-73  PWR     17 miles W of McCandless,  PA
# 4   05000456  NPF-72  PWR       20 miles SSW of Joliet,  IL
# 5   05000457  NPF-77  PWR       20 miles SSW of Joliet,  IL
# 6   05000259  DPR-33  BWR     32 miles W of Huntsville,  AL
# 7   05000260  DPR-52  BWR     32 miles W of Huntsville,  AL
# 8   05000296  DPR-68  BWR     32 miles W of Huntsville,  AL
# 9   05000325  DPR-71  BWR     30 miles S of Wilmington,  NC
# 10  05000324  DPR-62  BWR     30 miles S of Wilmington,  NC
# 11  05000454  NPF-37  PWR      17 miles SW of Rockford,  IL
#
#                                      6  7
# 0    Entergy Nuclear Operations, Inc.   4
# 1    Entergy Nuclear Operations, Inc.   4
# 2   FirstEnergy Nuclear Operating Co.   1
# 3   FirstEnergy Nuclear Operating Co.   1
# 4          Exelon Generation Co., LLC   3
# 5          Exelon Generation Co., LLC   3
# 6          Tennessee Valley Authority   2
# 7          Tennessee Valley Authority   2
# 8          Tennessee Valley Authority   2
# 9           Duke Energy Progress, LLC   2
# 10           Duke Energy Progress, LLC  2
# 11         Exelon Generation Co., LLC   3
